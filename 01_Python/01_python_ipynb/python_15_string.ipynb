# %% [markdown]
# 문자열 기본

# %%
a = [1,2,3,4,5]

print(a[0])
print(a[1:3])
# Out:
# 1
# [2, 3]

# %%
s = "멀티캠퍼스_데이터분석 및 개발자과정_8기"

# %%
#count() : 찾을 문자열이 몇 개 있는 지 , 개수를 세는 함수

s.count("-")
# Out:
# 0

# %%
#find()함수
#찾는 문자열이 없으면 -1

s.find("분석")
# Out:
# 9

# %%
#index(): find()랑 유사하다 단, 없으면 에러 발생

# %%
#join()

a = ','
a.join(['my','name','is'])
# Out:
# 'my,name,is'

# %%
a = '/'
a.join(['my','name','is'])
# Out:
# 'my/name/is'

# %% [markdown]
# 문자열 중요 내장 함수

# %%
#upper/ lower

#upper : 전부 대문자로 변환
#lower : 전부 소문자로 변환

#replace()
a = 'Multicampus'

a.replace('c','C')
# Out:
# 'MultiCampus'

# %%
b = 'd  e  r'
c =  b.replace(' ',"")
print(b)
# Out:
# d  e  r

# %%
ai = '나는 인공지능 데이터 분석가 및 개발자다'

print(ai)
print(ai.split(' '))
# Out:
# 나는 인공지능 데이터 분석가 및 개발자다
# ['나는', '인공지능', '데이터', '분석가', '및', '개발자다']

# %%
f = "           이예진      "

print(f.lstrip()) #왼쪽공백을 없앰
print(f.rstrip()) #오른쪽공백을 없앰
print(f.strip())  #양쪽 공백을 없앰
# Out:
# 이예진
#            이예진
# 이예진

# %%
a.swapcase()
# Out:
# 'mULTICAMPUS'

# %% [markdown]
# 문자열 분리 및 결합
#
# * split(), join(),splitlines()

# %%
s = "닥터윌과 함께 파이썬을 열공하는 중... 한숨이 나옴"

s.split()
# Out:
# ['닥터윌과', '함께', '파이썬을', '열공하는', '중...', '한숨이', '나옴']

# %%
a = '5시:40분: 끝내줄까?'
a.split(':')
# Out:
# ['5시', '40분', ' 끝내줄까?']

# %%
b = '제발요\n안그러면\n수업거부할꺼예요'
print(b)
b.split('\n')
# Out:
# 제발요
# 안그러면
# 수업거부할꺼예요
# ['제발요', '안그러면', '수업거부할꺼예요']

# %%
b.splitlines()
# Out:
# ['제발요', '안그러면', '수업거부할꺼예요']

# %%
c = "/"
c.join('이예진')
# Out:
# '이/예/진'

# %%
#문자열

s = input('날짜(연/월/일) 입력하세요: ')
print(s)

s.split('.')
# Out:
# 날짜(연/월/일) 입력하세요: 2024.03.22
# 2024.03.22
# ['2024', '03', '22']

# %%
split_s = s.split('.')

print(split_s[0])
# Out:
# 2024

# %%
print("입력한 날짜의 10년 후: ", end="")
print(str(int(split_s[0])+10) + "년", end="")
# Out:
# 입력한 날짜의 10년 후: 2034년

# %%
s='Multicampus'
s.isdigit()
# Out:
# False
